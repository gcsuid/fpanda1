# %%
import pandas as pd

# %%
# Load the FD Report
df_fd = pd.read_excel("Report FD.xlsx")  # Update filename accordingly

# %%
df_fd['NUM_TAR'] = df_fd['NUM_TAR'].astype(str).str.strip()

# %%
df_fd['LIQ_6_TARJETA'] = df_fd['NUM_TAR'].str[:6]

# %%
df_fd['LIQ_4_TARJETA'] = df_fd['NUM_TAR'].str[-4:]

# %%
df_fd
# Out:
#                ID  EMPRESA      FPRES  TIPO_REG     NUM_COM  \
# 0      1688213153     9137 2022-01-03         1  26364968.0
# 1      1688213154     9137 2022-01-03         1  26364968.0
# 2      1688213155     9137 2022-01-03         1  26364968.0
# 3      1688213156     9137 2022-01-03         1  26364968.0
# 4      1688213159     9137 2022-01-03         1  26364968.0
# ...           ...      ...        ...       ...         ...
# 33416  1690427765     9137 2022-01-03         1  27154571.0
# 33417  1690427786     9137 2022-01-03         1  27154571.0
# 33418  1690427958     9137 2022-01-03         1  27154571.0
# 33419  1690427970     9137 2022-01-03         1  27154571.0
# 33420  1690428173     9137 2022-01-03         1  27154571.0
#
#                                    COD_OP TIPO_APLIC  LOTE  COD_BCO  COD_CASA  \
# 0      0005 - (A) comprob. de compra en $          +   726      914         1
# 1      0005 - (A) comprob. de compra en $          +   726      914         1
# ...

# %%
df_fd.to_excel("FD_Report_Normalized.xlsx", index=False)
