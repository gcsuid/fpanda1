# %%
import pandas as pd

# %%
df_dota = pd.read_excel("DB_DOTA_Normalized.xlsx")

# %%
df_comercios = pd.read_excel("Parametria Comercios.xlsx")

# %%
df_comercios_estandar = df_comercios[df_comercios['Comercios_TYPE'] == 'ESTANDAR']

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df_dota
# Out:
#        CARD_FOUR_LAST_DIGITS  CARD_ISSUER_ID CARD_ISSUER_NAME  \
# 0                       7978               1             Visa
# 1                       7976               1             Visa
# 2                       5979               1             Visa
# 3                       5977           12433       Visa Ahora
# 4                       7896             316             BBVA
# ...                      ...             ...              ...
# 56147                   7896               1             Visa
# 56148                   6668             279    Banco Galicia
# 56149                   9977               1             Visa
# 56150                     58               1             Visa
# 56151                   6989               1             Visa
#
#        CARD_SIX_FIRST_DIGITS  MOV_AMOUNT           MOV_CREATED_DATE  \
# 0                     588559     2600.00  2022-01-02T23:13:36-04:00
# 1                     558766     1709.00  2022-01-02T23:13:35-04:00
# ...

# %%
df_comercios_estandar
# Out:
#       Comercios Comercios_TYPE
# 0    8234815397       ESTANDAR
# 1    8236841177       ESTANDAR
# 2    8354313702       ESTANDAR
# 3    8354313710       ESTANDAR
# 4    9133209072       ESTANDAR
# ..          ...            ...
# 667    51970986       ESTANDAR
# 668    70225545       ESTANDAR
# 669    74616608       ESTANDAR
# 670         969       ESTANDAR
# 671    47834775       ESTANDAR
#
# [487 rows x 2 columns]

# %%
df_merged = df_dota.merge(
    df_comercios_estandar[['Comercios']],
    how='inner',
    left_on='GTWT_MERCHANT_NUMBER',
    right_on='Comercios'
)

# %%
df_merged = df_merged.drop(columns=['Comercios'])

# %%
df_merged
# Out:
#        CARD_FOUR_LAST_DIGITS  CARD_ISSUER_ID CARD_ISSUER_NAME  \
# 0                       7978               1             Visa
# 1                       7976               1             Visa
# 2                       5979               1             Visa
# 3                       5977           12433       Visa Ahora
# 4                       7896             316             BBVA
# ...                      ...             ...              ...
# 56147                   7896               1             Visa
# 56148                   6668             279    Banco Galicia
# 56149                   9977               1             Visa
# 56150                     58               1             Visa
# 56151                   6989               1             Visa
#
#        CARD_SIX_FIRST_DIGITS  MOV_AMOUNT           MOV_CREATED_DATE  \
# 0                     588559     2600.00  2022-01-02T23:13:36-04:00
# 1                     558766     1709.00  2022-01-02T23:13:35-04:00
# ...

# %%
df_merged.to_excel("DB_DOTA_Filtered_by_COMERCIOS.xlsx", index=False)
